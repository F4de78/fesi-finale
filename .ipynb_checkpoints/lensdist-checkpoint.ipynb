# %% [markdown]
# # Distorsioni causate da lenti: Barrel e Pincushion
# ## Laboratorio FESI 2022
# ### Marco Zucca s4828628

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import data, io, color


from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
img = io.imread('test_grid.jpg')
target = io.imread('target.jpg')

original = io.imread('turing.jpg')
pin = io.imread('turing_pincushion.jpg')
barrel = io.imread('turing_barrel.jpg')

#img = color.rgb2gray(rgb_img)
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(target)

plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.imshow(original)
plt.subplot(1,3,2)
plt.imshow(barrel)
plt.subplot(1,3,3)
plt.imshow(pin)

# %%
def rotationCenter(image, angle):
    width,height=image.shape[:2]   
    dst = np.zeros((width, height, 3), dtype=np.uint8)
    # INVERSE MAPPING Loop over the destination, not the source, to ensure that you cover
    # every destination pixel exactly 1 time.
    for u in range(width):
        for v in range(height):
            #traslate
            x1 = u-width/2
            y1 = v-height/2
            #rotate
            x2 = x1*np.cos(-angle)+ y1*np.sin(-angle)
            y2 = -x1*np.sin(-angle)+y1*np.cos(-angle)
            #traslate
            x = x2+width/2
            y = y2+height/2
            
            
            intx, inty = int(x), int(y)
            # bilinear interpolation
            fracx, fracy = x%1, y%1
            if 0 < x < width-1 and 0 < y < height-1:
                #dst[u, v] = image[intx, inty] # qui tronco
                dst[u, v] = fracx*fracy*image[intx, inty]+(1-fracx)*fracy*image[intx+1, inty]+fracx*(1-fracy)*image[intx, inty+1]+(1-fracx)*(1-fracy)*image[intx+1, inty+1]
    return dst

# %%
#converte le coordinate cartesiane in polari
def cart2pol(x,y):
    theta = np.arctan2(y,x)
    rho = np.sqrt(x**2 + y**2)
    return (theta, rho)

# %%
#converte le coordinate polari in cartesiane
def pol2cart(theta,rho):
    x = rho*np.cos(theta)
    y = rho*np.sin(theta)
    return (x, y)

# %% [markdown]
# fonti:
# - https://www.mathworks.com/matlabcentral/fileexchange/37980-barrel-and-pincushion-lens-distortion-correction
#
#
# - wikipedia

# %%
# Prende un'immagine e applica la distorisone "barrel" partendo dal punto definito da wpx e wpy con fattori rf1 e rf2
def lensDistorsion(image,wpx,wpy,scale,rf):
    width,height=image.shape[:2]
    print(width,height)
    if  (wpx > width or wpx < 0) or (wpy > height or wpy < 0):
        print("Punto non valido")
        return
    dst = np.zeros((width, height, 3), dtype=np.uint8)
    R = np.sqrt((width/2)**2 + (height/2)**2)

    for u in range(width):
        for v in range(height):
            
            x1 = u-wpx
            y1 = v-wpy
            
            x2 /= scale
            y2 /= scale
            
            #converte da cordinate cartesaine a polari
            theta,r = cart2pol(x2,y2)
            #normalizzazione
            r = r/R
            #modello
            s = r*(1 + rf*(r**2))
            #de-normalizza
            s2 = s*R
            #riconverte da cordiante poalri a cartesiane
            x4,y4 = pol2cart(theta,s2)
            #trasla al punto originario
            x = x3+wpx
            y = y3+wpy

            
            intx, inty = int(x), int(y)
            # bilinear interpolation
            fracx, fracy = x%1, y%1
            #interp = fracx*fracy + (1-fracx)*fracy + fracx*(1-fracy) + (1-fracx)*(1-fracy)
            if 0 < x < width-1 and 0 < y < height-1:
                #dst[u, v] = image[intx, inty] # qui tronco
                dst[u, v] = fracx*fracy*image[intx, inty]+(1-fracx)*fracy*image[intx+1, inty]+fracx*(1-fracy)*image[intx, inty+1]+(1-fracx)*(1-fracy)*image[intx+1, inty+1]
    return dst

# %%
def lensDistorsionCenter(image,scale,rf):
    width,height=image.shape[:2]
    dst = np.zeros((width, height, 3), dtype=np.uint8)
    R = np.sqrt((width/2)**2 + (height/2)**2)
    w2 = width/2
    h2 = height/2
    
    for u in range(width):
        for v in range(height):
            #trasla al centro
            x2 = u-w2
            y2 = v-h2
            #scala se necessario
            x2 /= scale
            y2 /= scale
            #converte da cordinate cartesaine a polari
            theta,r = cart2pol(x2,y2)
            #normalizzazione
            r = r/R
            #modello
            s = r*(1 + rf*(r**2))
            #de-normalizza
            s2 = s*R
            #riconverte da cordiante poalri a cartesiane
            x4,y4 = pol2cart(theta,s2)
            #traasla al punto originario
            x = x4+w2
            y = y4+h2
            
            intx, inty = int(x), int(y)
            # bilinear interpolation
            fracx, fracy = x%1, y%1
            #interp = fracx*fracy + (1-fracx)*fracy + fracx*(1-fracy) + (1-fracx)*(1-fracy)
            if 0 < x < width-1 and 0 < y < height-1:
                dst[u, v] = image[intx, inty] # qui tronco
                #dst[u, v] = fracx*fracy*image[intx, inty]+(1-fracx)*fracy*image[intx+1, inty]+fracx*(1-fracy)*image[intx, inty+1]+(1-fracx)*(1-fracy)*image[intx+1, inty+1]
    return dst

# %% [markdown]
# ### Immagini test

# %%
imgBarrel = lensDistorsionCenter(img,1,+0.3)
imgPin = lensDistorsionCenter(img,0.9,-0.3)

plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.title("Originale")
plt.imshow(img)
plt.subplot(1,3,3)
plt.title("Distorsione barrel")
plt.imshow(imgBarrel)
plt.subplot(1,3,2)
plt.title("Distorsione pincushion")
plt.imshow(imgPin)

# %%
imgBarrel = lensDistorsionCenter(target,1,+0.3)
imgPin = lensDistorsionCenter(target,0.9,-0.3)

plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.title("Originale")
plt.imshow(target)
plt.subplot(1,3,3)
plt.title("Distorsione barrel")
plt.imshow(imgBarrel)
plt.subplot(1,3,2)
plt.title("Distorsione pincushion")
plt.imshow(imgPin)

# %% [markdown]
# ### Volti

# %%
pinCorrection = lensDistorsionCenter(pin,2,+1.6)
barrelCorrection = lensDistorsionCenter(barrel,1,-0.3)

plt.figure(figsize=(20,20))
plt.subplot(1,3,1)
plt.title("Originale")
plt.imshow(original)
plt.subplot(1,3,3)
plt.title("Correzione barrel")
plt.imshow(barrelCorrection)
plt.subplot(1,3,2)
plt.title("Correzione pincushion")
plt.imshow(pinCorrection)
